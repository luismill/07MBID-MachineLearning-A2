# %% [markdown]
# #  El Problema

# %% [markdown]
# Vamos a utilizar los datos de la competición de predicción de los datos del Dengue. Mas información en [enlace](https://www.drivendata.org/competitions/44/dengai-predicting-disease-spread/)
#
# El objetivo del ejercicio es por un lado jugar con una red neuronal para resolver un problema de regresión y por otro participar en una competición de datos.

# %% [markdown]
# # Setting Preliminares

# %% [markdown]
# Antes de empezar cualquier análisis hay que asegurar que las librerías básicas y de uso general (numpy, pandas, etc.) están correctamente importadas.

# %%
# carga de datos
import pandas as pd
import io
# from google.colab import files
# manipulación y visualización
import matplotlib.pyplot as plt
import numpy as np
import itertools
import seaborn as sns
import os

# %% [markdown]
# # Carga de Datos

# %% [markdown]
# En primer lugar cargamos los datos dentro del entorno con las funcionalidades que nos permite Google Colab

# %% [markdown]
# En primer lugar subimos los datos de entrenamiento sin campo objetivo (dengue_features_train)

# %%
train_feat = pd.read_csv('dengue_features_train.csv')
train_feat.head()
# Out:
#   city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  1990          18      1990-04-30  0.122600  0.103725  0.198483
# 1   sj  1990          19      1990-05-07  0.169900  0.142175  0.162357
# 2   sj  1990          20      1990-05-14  0.032250  0.172967  0.157200
# 3   sj  1990          21      1990-05-21  0.128633  0.245067  0.227557
# 4   sj  1990          22      1990-05-28  0.196200  0.262200  0.251200
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# 0  0.177617                 12.42             297.572857  ...
# 1  0.155486                 22.82             298.211429  ...
# 2  0.170843                 34.54             298.781429  ...
# 3  0.235886                 15.36             298.987143  ...
# 4  0.247340                  7.52             299.518571  ...
#
#    reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# 0                            32.00                             73.365714
# 1                            17.94                             77.368571
# 2                            26.10                             82.052857
# 3                            13.90                             80.337143
# 4                            12.20                             80.460000
#
#    reanalysis_sat_precip_amt_mm  reanalysis_specific_humidity_g_per_kg  \
# 0                         12.42                              14.012857
# 1                         22.82                              15.372857
# 2                         34.54                              16.848571
# 3                         15.36                              16.672857
# 4                          7.52                              17.210000
#
#    reanalysis_tdtr_k  station_avg_temp_c  station_diur_temp_rng_c  \
# 0           2.628571           25.442857                 6.900000
# 1           2.371429           26.714286                 6.371429
# 2           2.300000           26.714286                 6.485714
# 3           2.428571           27.471429                 6.771429
# 4           3.014286           28.942857                 9.371429
#
#    station_max_temp_c  station_min_temp_c  station_precip_mm
# 0                29.4                20.0               16.0
# 1                31.7                22.2                8.6
# 2                32.2                22.8               41.4
# 3                33.3                23.3                4.0
# 4                35.0                23.9                5.8
#
# [5 rows x 24 columns]

# %%
train_feat.shape
# Out:
# (1456, 24)

# %% [markdown]
# Posteriormente subimos los datos que únicamente nos proporcionan el número de casos de dengue para las semanas de entrenamiento (dengue_labels_train)

# %%
train_labels = pd.read_csv('dengue_labels_train.csv')
train_labels.head()
# Out:
#   city  year  weekofyear  total_cases
# 0   sj  1990          18            4
# 1   sj  1990          19            5
# 2   sj  1990          20            4
# 3   sj  1990          21            3
# 4   sj  1990          22            6

# %% [markdown]
# Mezclamos los dos conjuntos de datos para tenerlos en un único dataframe

# %%
train = pd.merge(train_feat,train_labels,on=['city', 'year', 'weekofyear'])
train.head()
# Out:
#   city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  1990          18      1990-04-30  0.122600  0.103725  0.198483
# 1   sj  1990          19      1990-05-07  0.169900  0.142175  0.162357
# 2   sj  1990          20      1990-05-14  0.032250  0.172967  0.157200
# 3   sj  1990          21      1990-05-21  0.128633  0.245067  0.227557
# 4   sj  1990          22      1990-05-28  0.196200  0.262200  0.251200
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# 0  0.177617                 12.42             297.572857  ...
# 1  0.155486                 22.82             298.211429  ...
# 2  0.170843                 34.54             298.781429  ...
# 3  0.235886                 15.36             298.987143  ...
# 4  0.247340                  7.52             299.518571  ...
#
#    reanalysis_relative_humidity_percent  reanalysis_sat_precip_amt_mm  \
# 0                             73.365714                         12.42
# 1                             77.368571                         22.82
# 2                             82.052857                         34.54
# 3                             80.337143                         15.36
# 4                             80.460000                          7.52
#
#    reanalysis_specific_humidity_g_per_kg  reanalysis_tdtr_k  \
# 0                              14.012857           2.628571
# 1                              15.372857           2.371429
# 2                              16.848571           2.300000
# 3                              16.672857           2.428571
# 4                              17.210000           3.014286
#
#    station_avg_temp_c  station_diur_temp_rng_c  station_max_temp_c  \
# 0           25.442857                 6.900000                29.4
# 1           26.714286                 6.371429                31.7
# 2           26.714286                 6.485714                32.2
# 3           27.471429                 6.771429                33.3
# 4           28.942857                 9.371429                35.0
#
#    station_min_temp_c  station_precip_mm  total_cases
# 0                20.0               16.0            4
# 1                22.2                8.6            5
# 2                22.8               41.4            4
# 3                23.3                4.0            3
# 4                23.9                5.8            6
#
# [5 rows x 25 columns]

# %%
train.shape
# Out:
# (1456, 25)

# %% [markdown]
# Finalmente subimos los datos para generar la evaluación final (dengue_features_test)

# %%
test = pd.read_csv('dengue_features_test.csv')
test.head()
# Out:
#   city  year  weekofyear week_start_date  ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  2008          18      2008-04-29  -0.0189 -0.018900  0.102729
# 1   sj  2008          19      2008-05-06  -0.0180 -0.012400  0.082043
# 2   sj  2008          20      2008-05-13  -0.0015       NaN  0.151083
# 3   sj  2008          21      2008-05-20      NaN -0.019867  0.124329
# 4   sj  2008          22      2008-05-27   0.0568  0.039833  0.062267
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# 0  0.091200                 78.60             298.492857  ...
# 1  0.072314                 12.56             298.475714  ...
# 2  0.091529                  3.66             299.455714  ...
# 3  0.125686                  0.00             299.690000  ...
# 4  0.075914                  0.76             299.780000  ...
#
#    reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# 0                            25.37                             78.781429
# 1                            21.83                             78.230000
# 2                             4.12                             78.270000
# 3                             2.20                             73.015714
# 4                             4.36                             74.084286
#
#    reanalysis_sat_precip_amt_mm  reanalysis_specific_humidity_g_per_kg  \
# 0                         78.60                              15.918571
# 1                         12.56                              15.791429
# 2                          3.66                              16.674286
# 3                          0.00                              15.775714
# 4                          0.76                              16.137143
#
#    reanalysis_tdtr_k  station_avg_temp_c  station_diur_temp_rng_c  \
# 0           3.128571           26.528571                 7.057143
# 1           2.571429           26.071429                 5.557143
# 2           4.428571           27.928571                 7.785714
# 3           4.342857           28.057143                 6.271429
# 4           3.542857           27.614286                 7.085714
#
#    station_max_temp_c  station_min_temp_c  station_precip_mm
# 0                33.3                21.7               75.2
# 1                30.0                22.2               34.3
# 2                32.8                22.8                3.0
# 3                33.3                24.4                0.3
# 4                33.3                23.3               84.1
#
# [5 rows x 24 columns]

# %%
test.shape
# Out:
# (416, 24)

# %% [markdown]
# # Preproceso
#
# Aquí irían todas las funciones y transformaciones que permitieran el uso de las variables en los siguientes clasificadores, por ejemplo la transformación de las variables categóricas en numéricas, etc.

# %%
train.drop(["week_start_date", "year", "weekofyear"], axis = 1, inplace = True)
test.drop(["week_start_date", "year", "weekofyear"], axis = 1, inplace = True)
train.head()
# Out:
#   city   ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  precipitation_amt_mm  \
# 0   sj  0.122600  0.103725  0.198483  0.177617                 12.42
# 1   sj  0.169900  0.142175  0.162357  0.155486                 22.82
# 2   sj  0.032250  0.172967  0.157200  0.170843                 34.54
# 3   sj  0.128633  0.245067  0.227557  0.235886                 15.36
# 4   sj  0.196200  0.262200  0.251200  0.247340                  7.52
#
#    reanalysis_air_temp_k  reanalysis_avg_temp_k  reanalysis_dew_point_temp_k  \
# 0             297.572857             297.742857                   292.414286
# 1             298.211429             298.442857                   293.951429
# 2             298.781429             298.878571                   295.434286
# 3             298.987143             299.228571                   295.310000
# 4             299.518571             299.664286                   295.821429
#
#    reanalysis_max_air_temp_k  ...  reanalysis_relative_humidity_percent  \
# 0                      299.8  ...                             73.365714
# 1                      300.9  ...                             77.368571
# 2                      300.5  ...                             82.052857
# 3                      301.4  ...                             80.337143
# 4                      301.9  ...                             80.460000
#
#    reanalysis_sat_precip_amt_mm  reanalysis_specific_humidity_g_per_kg  \
# 0                         12.42                              14.012857
# 1                         22.82                              15.372857
# 2                         34.54                              16.848571
# 3                         15.36                              16.672857
# 4                          7.52                              17.210000
#
#    reanalysis_tdtr_k  station_avg_temp_c  station_diur_temp_rng_c  \
# 0           2.628571           25.442857                 6.900000
# 1           2.371429           26.714286                 6.371429
# 2           2.300000           26.714286                 6.485714
# 3           2.428571           27.471429                 6.771429
# 4           3.014286           28.942857                 9.371429
#
#    station_max_temp_c  station_min_temp_c  station_precip_mm  total_cases
# 0                29.4                20.0               16.0            4
# 1                31.7                22.2                8.6            5
# 2                32.2                22.8               41.4            4
# 3                33.3                23.3                4.0            3
# 4                35.0                23.9                5.8            6
#
# [5 rows x 22 columns]

# %% [markdown]
# Trataremos los valores perdidos que los hay dado que nos evitarían tener un modelo de los datos que tenemos.

# %%
pd.isnull(train).sum()
# Out:
# city                                       0
# ndvi_ne                                  194
# ndvi_nw                                   52
# ndvi_se                                   22
# ndvi_sw                                   22
# precipitation_amt_mm                      13
# reanalysis_air_temp_k                     10
# reanalysis_avg_temp_k                     10
# reanalysis_dew_point_temp_k               10
# reanalysis_max_air_temp_k                 10
# reanalysis_min_air_temp_k                 10
# reanalysis_precip_amt_kg_per_m2           10
# reanalysis_relative_humidity_percent      10
# reanalysis_sat_precip_amt_mm              13
# reanalysis_specific_humidity_g_per_kg     10
# reanalysis_tdtr_k                         10
# station_avg_temp_c                        43
# station_diur_temp_rng_c                   43
# station_max_temp_c                        20
# station_min_temp_c                        14
# station_precip_mm                         22
# total_cases                                0
# dtype: int64

# %% [markdown]
# Los vamos a procesar de forma automática completandolos con el método ffill (con el valor previo)

# %%
train.interpolate(inplace=True)
pd.isnull(train).any()
# Out:
# city                                     False
# ndvi_ne                                  False
# ndvi_nw                                  False
# ndvi_se                                  False
# ndvi_sw                                  False
# precipitation_amt_mm                     False
# reanalysis_air_temp_k                    False
# reanalysis_avg_temp_k                    False
# reanalysis_dew_point_temp_k              False
# reanalysis_max_air_temp_k                False
# reanalysis_min_air_temp_k                False
# reanalysis_precip_amt_kg_per_m2          False
# reanalysis_relative_humidity_percent     False
# reanalysis_sat_precip_amt_mm             False
# reanalysis_specific_humidity_g_per_kg    False
# reanalysis_tdtr_k                        False
# station_avg_temp_c                       False
# station_diur_temp_rng_c                  False
# station_max_temp_c                       False
# station_min_temp_c                       False
# station_precip_mm                        False
# total_cases                              False
# dtype: bool

# %% [markdown]
# Y aplicamos lo mismo para el test

# %%
test.interpolate(inplace=True)
pd.isnull(test).any()
# Out:
# city                                     False
# ndvi_ne                                  False
# ndvi_nw                                  False
# ndvi_se                                  False
# ndvi_sw                                  False
# precipitation_amt_mm                     False
# reanalysis_air_temp_k                    False
# reanalysis_avg_temp_k                    False
# reanalysis_dew_point_temp_k              False
# reanalysis_max_air_temp_k                False
# reanalysis_min_air_temp_k                False
# reanalysis_precip_amt_kg_per_m2          False
# reanalysis_relative_humidity_percent     False
# reanalysis_sat_precip_amt_mm             False
# reanalysis_specific_humidity_g_per_kg    False
# reanalysis_tdtr_k                        False
# station_avg_temp_c                       False
# station_diur_temp_rng_c                  False
# station_max_temp_c                       False
# station_min_temp_c                       False
# station_precip_mm                        False
# dtype: bool

# %% [markdown]
# ### Selección de variables
# A continuación, se obtiene las estadísticas más relevantes de las variables para ver que forma tienen

# %%
train.describe()
# Out:
#            ndvi_ne      ndvi_nw      ndvi_se      ndvi_sw  \
# count  1456.000000  1456.000000  1456.000000  1456.000000
# mean      0.131490     0.127823     0.203130     0.201963
# std       0.137272     0.119478     0.073781     0.083491
# min      -0.406250    -0.456100    -0.015533    -0.063457
# 25%       0.037400     0.048092     0.154057     0.144455
# 50%       0.115550     0.115926     0.195664     0.190121
# 75%       0.231443     0.213429     0.247461     0.246579
# max       0.508357     0.454429     0.538314     0.546017
#
#        precipitation_amt_mm  reanalysis_air_temp_k  reanalysis_avg_temp_k  \
# count           1456.000000            1456.000000            1456.000000
# mean              45.702091             298.697750             299.221723
# std               43.651356               1.359878               1.260384
# min                0.000000             294.635714             294.892857
# 25%                9.785000             297.657857             298.257143
# 50%               38.320000             298.640000             299.285714
# 75%               70.227500             299.827500             300.207143
# max              390.600000             302.200000             302.928571
#
#        reanalysis_dew_point_temp_k  reanalysis_max_air_temp_k  \
# count                  1456.000000                1456.000000
# mean                    295.244555                 303.420158
# std                       1.525955                   3.233153
# min                     289.642857                 297.800000
# 25%                     294.117857                 301.000000
# 50%                     295.638571                 302.400000
# 75%                     296.457857                 305.500000
# max                     298.450000                 314.000000
#
#        reanalysis_min_air_temp_k  ...  reanalysis_relative_humidity_percent  \
# count                1456.000000  ...                           1456.000000
# mean                  295.718441  ...                             82.173009
# std                     2.559010  ...                              7.152190
# min                   286.900000  ...                             57.787143
# 25%                   293.900000  ...                             77.196429
# 50%                   296.200000  ...                             80.287857
# 75%                   297.900000  ...                             86.437500
# max                   299.900000  ...                             98.610000
#
#        reanalysis_sat_precip_amt_mm  reanalysis_specific_humidity_g_per_kg  \
# count                   1456.000000                            1456.000000
# mean                      45.702091                              16.744659
# std                       43.651356                               1.540958
# min                        0.000000                              11.715714
# 25%                        9.785000                              15.554643
# 50%                       38.320000                              17.084286
# 75%                       70.227500                              17.976071
# max                      390.600000                              20.461429
#
#        reanalysis_tdtr_k  station_avg_temp_c  station_diur_temp_rng_c  \
# count        1456.000000         1456.000000              1456.000000
# mean            4.900618           27.181438                 8.095505
# std             3.542762            1.281116                 2.127521
# min             1.357143           21.400000                 4.528571
# 25%             2.328571           26.314286                 6.528571
# 50%             2.857143           27.400000                 7.350000
# 75%             7.632143           28.130804                 9.603571
# max            16.028571           30.800000                15.800000
#
#        station_max_temp_c  station_min_temp_c  station_precip_mm  total_cases
# count         1456.000000         1456.000000        1456.000000  1456.000000
# mean            32.446497           22.098043          39.362294    24.675137
# std              1.959090            1.570524          47.285701    43.596000
# min             26.700000           14.700000           0.000000     0.000000
# 25%             31.100000           21.100000           8.850000     5.000000
# 50%             32.800000           22.200000          24.050000    12.000000
# 75%             33.900000           23.300000          53.900000    28.000000
# max             42.200000           25.600000         543.300000   461.000000
#
# [8 rows x 21 columns]

# %% [markdown]
# En el dataset aparecen varias variables repetidas, ya que provienen de bases de datos distintas: temperatura media, minima, máxima, precipitación total...
# Para reducir la dimensionalidad y eliminar variables que indican lo mismo y por tanto muy correlacionadas entre si, se van a transformar columnas para quedarse solo con la media de las variables repetidas.
# Como no todas las variables están en las mismas unidades, hay que convertirlas antes de hacer la  media. La temperatura está en Kelvin en las variables "reanalysis..." y en Celsius en las variables "station...". Para pasarla de Kelvin a Celsius hay que restarle 273.

# %%
# Temperatura media
train['temp_media'] = (train.reanalysis_air_temp_k - 273 + train.reanalysis_avg_temp_k - 273 + train.station_avg_temp_c)/3
test['temp_media'] = (test.reanalysis_air_temp_k - 273 + test.reanalysis_avg_temp_k - 273 + test.station_avg_temp_c)/3

# Precipitación total
train['prec_total'] = train[['precipitation_amt_mm','reanalysis_sat_precip_amt_mm', 'station_precip_mm']].mean(axis=1)
test['prec_total'] = test[['precipitation_amt_mm','reanalysis_sat_precip_amt_mm', 'station_precip_mm']].mean(axis=1)

# Temperatura máxima
train['temp_max'] = (train.station_max_temp_c + train.reanalysis_max_air_temp_k - 273)/2
test['temp_max'] = (test.station_max_temp_c + test.reanalysis_max_air_temp_k - 273)/2

# Temperatura mínima
train['temp_min'] = (train.station_min_temp_c + train.reanalysis_min_air_temp_k - 273)/2
test['temp_min'] = (test.station_min_temp_c + test.reanalysis_min_air_temp_k - 273)/2

# ndvi
train['ndvi_media'] = train[['ndvi_se','ndvi_sw', 'ndvi_ne', 'ndvi_nw']].mean(axis=1)
test['ndvi_media'] = test[['ndvi_se','ndvi_sw', 'ndvi_ne', 'ndvi_nw']].mean(axis=1)

train.drop(['reanalysis_air_temp_k', 'reanalysis_avg_temp_k', 'station_avg_temp_c', 'precipitation_amt_mm','reanalysis_sat_precip_amt_mm', 
            'station_precip_mm', 'station_max_temp_c', 'reanalysis_max_air_temp_k', 'station_min_temp_c', 'reanalysis_min_air_temp_k', 
            'ndvi_se','ndvi_sw', 'ndvi_ne', 'ndvi_nw'], 
           axis = 1, inplace = True)
test.drop(['reanalysis_air_temp_k', 'reanalysis_avg_temp_k', 'station_avg_temp_c', 'precipitation_amt_mm','reanalysis_sat_precip_amt_mm', 
            'station_precip_mm', 'station_max_temp_c', 'reanalysis_max_air_temp_k', 'station_min_temp_c', 'reanalysis_min_air_temp_k', 
            'ndvi_se','ndvi_sw', 'ndvi_ne', 'ndvi_nw'], 
           axis = 1, inplace = True)

# %% [markdown]
# Existen otras categorías del dataset que no aportan información valiosa y pueden ser borradas:
# Las variables que indican el rango de temperatura son redundantes, ya que indican la diferencia entre la máxima y la mínima, por lo que se pueden eliminar.
# También se elimina la variable "reanalysis_dew_point_temp_k", que indica la temperatura de rocío y es función de la humemdad y temperatura.
# Las variables "reanalysis_specific_humidity_g_per_kg" y "reanalysis_precip_amt_kg_per_m2" indican la humedad y precipitación en otras unidades, por lo que también son eliminadas.

# %%
train.drop(['station_diur_temp_rng_c', 'reanalysis_tdtr_k', 'reanalysis_dew_point_temp_k', 'reanalysis_specific_humidity_g_per_kg', 'reanalysis_precip_amt_kg_per_m2'], 
           axis = 1, inplace = True)
test.drop(['station_diur_temp_rng_c', 'reanalysis_tdtr_k', 'reanalysis_dew_point_temp_k', 'reanalysis_specific_humidity_g_per_kg', 'reanalysis_precip_amt_kg_per_m2'], 
           axis = 1, inplace = True)

# %% [markdown]
# Se cambia el nombre de la columna que no se modificó para simplificar el dataframe

# %%
train.rename({'reanalysis_relative_humidity_percent': 'rel_humidity'}, inplace=True, axis=1)
test.rename({'reanalysis_relative_humidity_percent': 'rel_humidity'}, inplace=True, axis=1)

# %% [markdown]
# El dataset queda de la siguiente manera, con 6 características + la columna objetivo

# %%
train.describe()
# Out:
#        rel_humidity  total_cases   temp_media   prec_total     temp_max  \
# count   1456.000000  1456.000000  1456.000000  1456.000000  1456.000000
# mean      82.173009    24.675137    26.366970    43.588826    31.433328
# std        7.152190    43.596000     1.187925    39.250335     2.447055
# min       57.787143     0.000000    23.130476     0.000000    26.100000
# 25%       77.196429     5.000000    25.441488    12.725000    29.750000
# 50%       80.287857    12.000000    26.386905    35.180000    31.100000
# 75%       86.437500    28.000000    27.366310    63.483333    32.950000
# max       98.610000   461.000000    29.202381   304.800000    39.050000
#
#           temp_min   ndvi_media
# count  1456.000000  1456.000000
# mean     22.408242     0.166101
# std       1.923175     0.091098
# min      15.150000    -0.092565
# 25%      21.100000     0.099902
# 50%      22.300000     0.146983
# 75%      24.100000     0.225478
# max      25.900000     0.503982

# %%
train.dtypes
# Out:
# city             object
# rel_humidity    float64
# total_cases       int64
# temp_media      float64
# prec_total      float64
# temp_max        float64
# temp_min        float64
# ndvi_media      float64
# dtype: object

# %% [markdown]
# Como tenemos 2 ciudades distintas, que pueden tener comportamientos diferentes, haremos un modelo para cada ciudad. Para ello dividimos el dataset en 2.

# %%
train_sj = train[train.city == 'sj']
train_sj.drop('city', axis=1, inplace=True)
train_iq = train[train.city == 'iq']
train_iq.drop('city', axis=1, inplace=True)
test_sj = test[test.city == 'sj']
test_sj.drop('city', axis=1, inplace=True)
test_iq = test[test.city == 'iq']
test_iq.drop('city', axis=1, inplace=True)
print("train_sj shape: ", train_sj.shape)
print("train_iq shape: ", train_iq.shape)
print("test_sj shape: ", test_sj.shape)
print("test_iq shape: ", test_iq.shape)
# Out:
# train_sj shape:  (936, 7)
# train_iq shape:  (520, 7)
# test_sj shape:  (260, 6)
# test_iq shape:  (156, 6)
# d:\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
# Se obtienen los coeficientes de correlacion para lo que hay que trasponer el dataframe
R_sj = np.corrcoef(np.transpose(train_sj))
R_iq = np.corrcoef(np.transpose(train_iq))

# Gráfico de la matriz de correlaciones
sns.set(style="whitegrid")
mask = np.zeros_like(R_sj, dtype=bool)
mask[np.triu_indices_from(mask)] = True

f, (ax1 , ax2) = plt.subplots(1, 2, figsize=(20, 10))

cmap = sns.diverging_palette(200, 10, as_cmap=True)

sns.heatmap(R_sj, mask=mask, cmap=cmap, vmax=.8,
            square=True, xticklabels=train_sj.columns, yticklabels=train_sj.columns,
            linewidths=.5, cbar_kws={"shrink": .5}, ax=ax1)

sns.heatmap(R_iq, mask=mask, cmap=cmap, vmax=.8,
            square=True, xticklabels=train_iq.columns, yticklabels=train_iq.columns,
            linewidths=.5, cbar_kws={"shrink": .5}, ax=ax2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Se observa que existen variables bastante correladas entre sí, como era de esperar: precipitación con la humedad, temperatura mínima con la media, ndvi con temperatura máxima y mínima. De momento no se elimina ninguna más hasta avanzar más con la exploración.
# También se ve que las variables más correlacionadas con total_cases son: temp_media, temp_min y city_bin. Estas son las que serán las más importantes en el modelo.

# %% [markdown]
# ### Eliminación de outliers
# Para ver si hay outliers presentes en el dataset, se dibujan los boxplots de cada columna.

# %%
f, (ax1 , ax2) = plt.subplots(1, 2, figsize=(20, 10))
train_sj.boxplot(fontsize=15, rot=45, ax=ax1)
train_iq.boxplot(fontsize=15, rot=45, ax=ax2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Se borran los outliers observados, analizados con más profundidad en la actividad 1

# %%
print('Outliers eliminados para San Juan: ', len(train_sj[train_sj.total_cases > 300]) + len(train_sj[train_sj.prec_total > 200]),
    ' (', round((len(train_sj[train_sj.total_cases > 300]) + len(train_sj[train_sj.prec_total > 200]))/len(train_sj)*100,2), '%)')
print('Outliers eliminados para Iquitos: ', len(train_iq[train_iq.total_cases > 50]) + len(train_iq[train_iq.prec_total > 200]),
    ' (', round((len(train_iq[train_iq.total_cases > 50]) + len(train_iq[train_iq.prec_total > 200]))/len(train_iq)*100,2), '%)')
# Out:
# Outliers eliminados para San Juan:  17  ( 1.82 %)
# Outliers eliminados para Iquitos:  7  ( 1.35 %)

# %%
train_sj.drop(train_sj[train_sj.total_cases > 300].index, inplace=True)
train_sj.drop(train_sj[train_sj.prec_total > 200].index, inplace=True)
train_iq.drop(train_iq[train_iq.total_cases > 50].index, inplace=True)
train_iq.drop(train_iq[train_iq.prec_total > 200].index, inplace=True)
# Out:
# d:\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %% [markdown]
# ### Normalización
# Por último, se normalizan todas las variables para que las técnicas de aprendizaje automático funcionen mejor.

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train_sj_norm = scaler.fit_transform(train_sj.drop('total_cases', axis=1))
X_test_sj_norm = scaler.transform(test_sj)
X_train_iq_norm = scaler.fit_transform(train_iq.drop('total_cases', axis=1))
X_test_iq_norm = scaler.transform(test_iq)
print('Máximos train: ', X_test_sj_norm.max(axis=0))
print('Mínimos train: ', X_test_sj_norm.min(axis=0))
print('Máximos test: ', X_test_sj_norm.max(axis=0))
print('Mínimos test: ', X_test_sj_norm.min(axis=0))
# Out:
# Máximos train:  [0.9747152  0.94439652 0.84254687 1.         1.05555556 0.95363077]
# Mínimos train:  [-0.08828841  0.14696887  0.          0.01481481  0.23611111 -0.00202769]
# Máximos test:  [0.9747152  0.94439652 0.84254687 1.         1.05555556 0.95363077]
# Mínimos test:  [-0.08828841  0.14696887  0.          0.01481481  0.23611111 -0.00202769]

# %% [markdown]
# # Construcción y evaluación preliminar del modelo

# %%
from sklearn import linear_model
y_train_sj = train_sj['total_cases']
y_train_iq = train_iq['total_cases']
model = linear_model.LinearRegression()
model_sj = model.fit(X_train_sj_norm, y_train_sj)
model_iq = model.fit(X_train_iq_norm, y_train_iq)

# %%
figs, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))

train_sj['predicciones'] = model.predict(X_train_sj_norm)
train_iq['predicciones'] = model.predict(X_train_iq_norm)

train_sj.total_cases.plot(ax=axes[0], label="Real")
train_sj.predicciones.plot(ax=axes[0], label='Predicción')

train_iq.total_cases.plot(ax=axes[1], label="Real")
train_iq.predicciones.plot(ax=axes[1], label='Predicción')
# Out:
# C:\Users\luism\AppData\Local\Temp/ipykernel_5504/1744813703.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_sj['predicciones'] = model.predict(X_train_sj_norm)
# C:\Users\luism\AppData\Local\Temp/ipykernel_5504/1744813703.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_iq['predicciones'] = model.predict(X_train_iq_norm)
# <AxesSubplot:>

# %% [markdown]
# # Generación del Resultado Final

# %% [markdown]
# Generamos el fichero de salida segun el Submission format

# %% [markdown]
# * Realizamos la predicción sobre el test

# %%
y_pred_sj = model.predict(X_test_sj_norm)
y_pred_iq = model.predict(X_test_iq_norm)
type(y_pred_sj)
# Out:
# numpy.ndarray

# %%
y_pred = np.concatenate((y_pred_sj, y_pred_iq), axis=None)
y_pred
# Out:
# array([ 3.30894862,  4.22962376,  5.1557122 ,  3.2736533 ,  3.83766228,
#         6.15544329,  6.65209422,  6.20645842,  7.86413984,  8.88608349,
#         7.52888235,  8.44994932,  7.85135655,  8.29648989,  9.47573029,
#         8.63102819,  9.22454984,  9.60560702,  9.17491249,  7.99947674,
#         8.55488963,  7.72829246,  7.31723947,  7.30774551,  5.89963309,
#         6.19149316,  6.42050295,  8.26053031,  6.48881814,  6.40852304,
#         4.75485748,  0.47806538,  2.1633557 ,  3.35796448,  0.77941623,
#         0.13644791,  0.40569999,  4.19821453,  3.31013816,  4.43071121,
#         2.4694057 ,  1.08238903, -0.55833684, -0.67836813,  1.84237785,
#        -0.74357854, -0.75433483, -0.21952518, -1.31423426,  1.11690614,
#         2.3962783 ,  1.81055044,  3.19054242,  2.9936514 ,  5.9352193 ,
#         5.9800724 ,  9.03482136,  5.71555357,  6.96037551,  7.8381305 ,
#         6.66752957,  8.20849866,  7.96125851,  9.42595951,  9.57804625,
#         9.50723713,  9.19540994,  8.66937378,  9.81574038,  8.96902386,
#         7.73558113,  9.3837257 ,  8.03320635,  7.43640437,  9.30728804,
#         9.62827535,  9.65292345,  8.92723529,  7.14512269,  6.97305779,
#         7.91244591,  7.05242586,  7.42995069,  5.56106089,  6.42837373,
#         5.41659287,  4.17827766,  3.75753397,  3.33679028,  2.3627643 ,
#         5.45349737,  4.15405385,  1.11269277,  0.66539699,  2.880956  ,
#         2.92842696,  5.67437197,  1.46613988,  1.65939406,  5.45281007,
#         5.22015238,  0.26032135,  2.53357593,  4.40335225,  8.54551494,
#         6.76459525,  6.70410169,  8.59501642,  7.92159933, 10.89888986,
#        10.26043565,  9.31216722,  9.08743571,  9.50737502, 10.72947678,
#         9.72922845, 10.31198929,  9.82227962, 10.39425619,  9.49638313,
#        10.25673056,  9.15156313,  9.99356253,  8.91339319, 10.6931455 ,
#         8.76412643,  9.21666776,  9.4919368 ,  9.40993005,  7.26861075,
#         5.4899456 ,  7.17985422,  8.20087823,  5.08474052,  3.01278481,
#         2.25731533, -3.11161326,  4.37900725,  1.60250781,  2.73471467,
#         1.72562509,  2.99867408,  4.20402777,  3.13571852,  2.00944835,
#         2.83325818,  3.87772976,  2.82874274, -0.76590577,  0.94862352,
#        -1.8636961 , -0.08468997,  2.35338453,  4.15419453,  1.89690062,
#         3.46018418,  3.10526474,  5.87037237,  3.06500625,  5.20147077,
#         8.13176216,  9.58384326,  8.75037854,  9.92738775,  9.44672796,
#         9.33642993,  9.84668044,  9.86981744,  8.39328265, 10.5437576 ,
#         9.70222072, 10.58046484,  8.86079186, 10.70549413,  9.24611239,
#         8.64511617,  8.95306587,  7.64760331,  9.35784077,  8.7331522 ,
#         7.91868799,  7.30910947,  6.3456581 ,  8.53162277,  6.66226973,
#         7.96956477,  7.5008541 ,  6.45343053,  4.57358664,  6.84940291,
#         1.68120167,  2.54019017,  3.60962156,  3.71138192,  2.46087305,
#         1.47347518,  1.54423959,  2.5984172 ,  2.05770358,  1.56061783,
#         2.56777337,  2.69757987,  2.3346227 ,  1.64505708,  3.75752883,
#         3.91310079,  4.26043564,  2.47712177,  0.2852375 ,  6.0545031 ,
#         6.07866203,  8.78364193,  7.75548928,  5.57044721,  7.78909415,
#         7.71371423,  8.32664228,  8.7842916 ,  8.34558468,  8.73782864,
#         9.56028728, 10.08922805,  8.88679906,  9.57280175,  9.58991673,
#         9.80706831,  8.74844015,  8.52171117,  7.9492475 ,  8.48365691,
#         9.47412746,  8.68053563,  8.13490858,  9.25442263,  8.88754495,
#         8.917016  ,  7.91204544,  7.67469942,  9.08685032,  7.24125583,
#         5.98512309,  4.45545769,  3.43130869,  5.45738745,  3.86497317,
#         1.98116887,  1.61307195,  3.22173223,  1.58777012,  0.63610994,
#         0.25264772,  1.84473909,  0.87481566, -1.35443515, -1.42966092,
#         3.96508579,  3.16929182,  5.29250455,  5.41219689,  3.93297729,
#         7.68950777,  5.85624921,  7.42553287,  2.00840618,  4.84435116,
#         6.59768198,  1.80152203,  6.77067906,  4.77828421,  7.33900402,
#         5.9579001 ,  6.49013249,  7.53982397,  6.24446536,  7.15181345,
#         7.95292745,  7.89003966,  9.51201526, 10.24657704,  7.09755007,
#         7.56505067,  8.41199675, 10.36422591,  9.04459655,  9.13081883,
#         6.60130091,  6.7607893 ,  6.31898332,  8.28320718,  6.96469852,
#         5.84529033,  7.23849308,  7.79128339,  8.09491074,  9.07259383,
#         8.52259346,  7.55851517,  6.72083932,  8.50717097,  7.90400431,
#         8.96536797,  6.32524087,  7.28774777,  9.25603753,  9.23375623,
#         4.02083056,  6.87124369,  6.92015833,  6.49531949,  4.6782909 ,
#         4.77915694,  2.53375918,  4.31769179,  5.84892829,  2.28874495,
#         4.43724106,  5.72142173,  3.9178069 ,  4.37778242,  2.98800837,
#         5.00142292,  4.45899746,  4.08677937,  6.78705482,  5.4981067 ,
#         6.5316514 ,  5.7986651 ,  8.074044  , 10.71831522,  6.7243369 ,
#         7.49104069,  8.24594637,  8.72812936,  8.09738934,  8.8537268 ,
#         9.66057732,  8.14849821,  7.97776466, 10.74376021,  8.24887881,
#         8.10632526,  7.40903011,  6.38161911,  8.38646152,  7.7721939 ,
#         6.74374875,  7.75714284,  6.74203782,  7.78643033,  6.33805536,
#         5.31408516,  9.38731558,  7.25422472,  9.9877554 ,  9.49633629,
#         7.29210486,  7.57619585,  4.40853638,  7.50318888,  5.76690714,
#         5.25965178,  6.91305896,  1.6504651 ,  5.22245711,  5.39118903,
#         4.37814311,  3.84354926,  6.01754613, -0.95309749,  2.75197997,
#         2.41009212,  3.45294359,  2.88213942,  4.54831615,  3.90893171,
#         5.80362267,  4.87202708,  6.41436391,  3.43140405,  9.03139865,
#         7.21246288,  7.15379036,  9.17584308,  8.80295814,  8.32841192,
#         9.9096109 ,  9.62649307,  9.5188659 ,  9.83428055, 10.22047894,
#         9.3889559 ,  5.52233103,  6.10404522,  9.14824786,  6.07331242,
#         9.9827602 ,  9.03253254,  8.58800495,  7.40840935,  8.88284766,
#        10.35857441, 10.17507705,  9.99829536,  9.9388621 ,  8.35837023,
#         8.81122845,  7.60619823,  2.42069567,  8.83245172,  8.46796058,
#         6.33064346,  7.60833567,  6.81310642,  5.15552932,  3.41415022,
#         5.8136051 ])

# %% [markdown]
# * Redondeamos el resultado

# %%
# round the result and cast to int
import numpy as np
y = np.rint(y_pred) # round
y = y.astype(int) # cast to int
res = np.hstack(y)

res
# Out:
# array([ 3,  4,  5,  3,  4,  6,  7,  6,  8,  9,  8,  8,  8,  8,  9,  9,  9,
#        10,  9,  8,  9,  8,  7,  7,  6,  6,  6,  8,  6,  6,  5,  0,  2,  3,
#         1,  0,  0,  4,  3,  4,  2,  1, -1, -1,  2, -1, -1,  0, -1,  1,  2,
#         2,  3,  3,  6,  6,  9,  6,  7,  8,  7,  8,  8,  9, 10, 10,  9,  9,
#        10,  9,  8,  9,  8,  7,  9, 10, 10,  9,  7,  7,  8,  7,  7,  6,  6,
#         5,  4,  4,  3,  2,  5,  4,  1,  1,  3,  3,  6,  1,  2,  5,  5,  0,
#         3,  4,  9,  7,  7,  9,  8, 11, 10,  9,  9, 10, 11, 10, 10, 10, 10,
#         9, 10,  9, 10,  9, 11,  9,  9,  9,  9,  7,  5,  7,  8,  5,  3,  2,
#        -3,  4,  2,  3,  2,  3,  4,  3,  2,  3,  4,  3, -1,  1, -2,  0,  2,
#         4,  2,  3,  3,  6,  3,  5,  8, 10,  9, 10,  9,  9, 10, 10,  8, 11,
#        10, 11,  9, 11,  9,  9,  9,  8,  9,  9,  8,  7,  6,  9,  7,  8,  8,
#         6,  5,  7,  2,  3,  4,  4,  2,  1,  2,  3,  2,  2,  3,  3,  2,  2,
#         4,  4,  4,  2,  0,  6,  6,  9,  8,  6,  8,  8,  8,  9,  8,  9, 10,
#        10,  9, 10, 10, 10,  9,  9,  8,  8,  9,  9,  8,  9,  9,  9,  8,  8,
#         9,  7,  6,  4,  3,  5,  4,  2,  2,  3,  2,  1,  0,  2,  1, -1, -1,
#         4,  3,  5,  5,  4,  8,  6,  7,  2,  5,  7,  2,  7,  5,  7,  6,  6,
#         8,  6,  7,  8,  8, 10, 10,  7,  8,  8, 10,  9,  9,  7,  7,  6,  8,
#         7,  6,  7,  8,  8,  9,  9,  8,  7,  9,  8,  9,  6,  7,  9,  9,  4,
#         7,  7,  6,  5,  5,  3,  4,  6,  2,  4,  6,  4,  4,  3,  5,  4,  4,
#         7,  5,  7,  6,  8, 11,  7,  7,  8,  9,  8,  9, 10,  8,  8, 11,  8,
#         8,  7,  6,  8,  8,  7,  8,  7,  8,  6,  5,  9,  7, 10,  9,  7,  8,
#         4,  8,  6,  5,  7,  2,  5,  5,  4,  4,  6, -1,  3,  2,  3,  3,  5,
#         4,  6,  5,  6,  3,  9,  7,  7,  9,  9,  8, 10, 10, 10, 10, 10,  9,
#         6,  6,  9,  6, 10,  9,  9,  7,  9, 10, 10, 10, 10,  8,  9,  8,  2,
#         9,  8,  6,  8,  7,  5,  3,  6])

# %%
y_pred_no_neg = res.copy()

# %%
y_pred_no_neg[y_pred < 0] = 0
y_pred_no_neg
# Out:
# array([ 3,  4,  5,  3,  4,  6,  7,  6,  8,  9,  8,  8,  8,  8,  9,  9,  9,
#        10,  9,  8,  9,  8,  7,  7,  6,  6,  6,  8,  6,  6,  5,  0,  2,  3,
#         1,  0,  0,  4,  3,  4,  2,  1,  0,  0,  2,  0,  0,  0,  0,  1,  2,
#         2,  3,  3,  6,  6,  9,  6,  7,  8,  7,  8,  8,  9, 10, 10,  9,  9,
#        10,  9,  8,  9,  8,  7,  9, 10, 10,  9,  7,  7,  8,  7,  7,  6,  6,
#         5,  4,  4,  3,  2,  5,  4,  1,  1,  3,  3,  6,  1,  2,  5,  5,  0,
#         3,  4,  9,  7,  7,  9,  8, 11, 10,  9,  9, 10, 11, 10, 10, 10, 10,
#         9, 10,  9, 10,  9, 11,  9,  9,  9,  9,  7,  5,  7,  8,  5,  3,  2,
#         0,  4,  2,  3,  2,  3,  4,  3,  2,  3,  4,  3,  0,  1,  0,  0,  2,
#         4,  2,  3,  3,  6,  3,  5,  8, 10,  9, 10,  9,  9, 10, 10,  8, 11,
#        10, 11,  9, 11,  9,  9,  9,  8,  9,  9,  8,  7,  6,  9,  7,  8,  8,
#         6,  5,  7,  2,  3,  4,  4,  2,  1,  2,  3,  2,  2,  3,  3,  2,  2,
#         4,  4,  4,  2,  0,  6,  6,  9,  8,  6,  8,  8,  8,  9,  8,  9, 10,
#        10,  9, 10, 10, 10,  9,  9,  8,  8,  9,  9,  8,  9,  9,  9,  8,  8,
#         9,  7,  6,  4,  3,  5,  4,  2,  2,  3,  2,  1,  0,  2,  1,  0,  0,
#         4,  3,  5,  5,  4,  8,  6,  7,  2,  5,  7,  2,  7,  5,  7,  6,  6,
#         8,  6,  7,  8,  8, 10, 10,  7,  8,  8, 10,  9,  9,  7,  7,  6,  8,
#         7,  6,  7,  8,  8,  9,  9,  8,  7,  9,  8,  9,  6,  7,  9,  9,  4,
#         7,  7,  6,  5,  5,  3,  4,  6,  2,  4,  6,  4,  4,  3,  5,  4,  4,
#         7,  5,  7,  6,  8, 11,  7,  7,  8,  9,  8,  9, 10,  8,  8, 11,  8,
#         8,  7,  6,  8,  8,  7,  8,  7,  8,  6,  5,  9,  7, 10,  9,  7,  8,
#         4,  8,  6,  5,  7,  2,  5,  5,  4,  4,  6,  0,  3,  2,  3,  3,  5,
#         4,  6,  5,  6,  3,  9,  7,  7,  9,  9,  8, 10, 10, 10, 10, 10,  9,
#         6,  6,  9,  6, 10,  9,  9,  7,  9, 10, 10, 10, 10,  8,  9,  8,  2,
#         9,  8,  6,  8,  7,  5,  3,  6])

# %% [markdown]
# * Generamos el fichero de salida

# %%
# generate output
test_original = pd.read_csv('dengue_features_test.csv')
output = pd.DataFrame({ 'city': test_original['city'], 'year': test_original['year'], 'weekofyear': test_original['weekofyear'], 
                       'total_cases': y_pred_no_neg})

name = 'LinearReg_Preproc_2modelos' + '_results.csv'
output.to_csv(name, index= False)
# from google.colab import files

#with open('result.csv', 'w') as f:
#  output.to_csv(f,  index = False)
  

#files.download('result.csv')

output.head()
# Out:
#   city  year  weekofyear  total_cases
# 0   sj  2008          18            3
# 1   sj  2008          19            4
# 2   sj  2008          20            5
# 3   sj  2008          21            3
# 4   sj  2008          22            4

# %%
output.tail()
# Out:
#     city  year  weekofyear  total_cases
# 411   iq  2013          22            8
# 412   iq  2013          23            7
# 413   iq  2013          24            5
# 414   iq  2013          25            3
# 415   iq  2013          26            6
